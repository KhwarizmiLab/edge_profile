# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-8b7bbc87-bdb5-7c67-b5cb-8cd0bdb79d74)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

if os.path.isdir("/content/drive/MyDrive/EZClone/edge_profile"):
    # %cd "/content/drive/MyDrive/EZClone/edge_profile"
# Out:
# /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile

# %%
import tensorflow as tf
print(tf.__version__)
tf.config.list_physical_devices('GPU')
# Out:
# 2.17.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !python tensorflow/model_inference.py -gpu 0 -model resnet50
# Out:
# 2025-01-14 05:13:29.407824: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-14 05:13:29.425613: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-14 05:13:29.430804: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-14 05:13:30.548915: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736831612.027341    7251 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1736831612.079828    7251 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1736831612.080068    7251 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1736831612.088125    7251 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1736831612.088336    7251 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1736831612.088475    7251 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1736831612.197377    7251 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1736831612.197673    7251 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-01-14 05:13:32.197860: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1736831612.197974    7251 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Running 1 inferences on resnet50 on /device:GPU:0...
# W0000 00:00:1736831622.112090    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.193258    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.194572    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.195806    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.197069    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.235628    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.237085    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.255388    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.571677    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.573244    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.574519    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.575789    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.577107    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.578513    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.634588    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.635983    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.637251    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.638543    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.639824    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.641195    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.642688    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.643987    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.645385    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.646767    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.709635    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.768038    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.880050    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.881233    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.882377    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.883551    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.884713    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.885893    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.887065    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.888238    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.889428    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.890621    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.891808    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.893000    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.894208    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.895573    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.914463    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.915669    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.917105    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.918564    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.919977    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.921433    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.922722    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.924204    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.925609    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.927011    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.928380    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.929990    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.931543    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.932883    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.934305    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.935860    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.943091    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.945088    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.947566    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.977831    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.979076    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.980316    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.981578    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.982816    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.984055    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.985290    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.986546    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.987784    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.989053    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.990339    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.991627    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.992917    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831622.994418    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.040864    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.042096    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.043287    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.044490    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.045752    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.046995    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.048242    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.049488    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.050740    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.052037    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.053319    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.054636    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.055978    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.057363    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.069889    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.071165    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.072945    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.074763    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.076464    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.078290    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.079727    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.081553    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.083276    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.085002    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.086627    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.088745    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.090762    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.092301    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.093843    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.095836    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.106086    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.110589    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.113517    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.132374    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.133648    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.134901    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.136166    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.137458    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.138762    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.140065    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.141398    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.142724    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.144051    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.145384    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.146747    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.148102    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.149622    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.270285    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.271588    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.272819    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.274064    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.275452    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.276858    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.278234    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.279626    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.281005    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.282463    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.283923    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.285440    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.287003    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.288410    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.301508    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.303019    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.304702    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.306359    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.308177    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.310091    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.312256    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.314567    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.316986    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.319415    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.321852    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.324347    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.326926    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.329516    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.332560    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.335718    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.338700    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.358684    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.398145    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.426220    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.427633    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.429016    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.430398    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.431765    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.433169    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.434605    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.436043    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.437521    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.439053    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.440616    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.442168    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.443804    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1736831623.445433    7251 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 111
# Completed.

# %%
# !python collect_tf_profiles.py -i 20 -input 0 -folder colab_zero_tf
# Out:
# Profiling resnet50 iteration 1/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.16mins per profile on resnet50, estimated time left 3.49 mins
# Profiling resnet50 iteration 2/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 3.18 mins
# Profiling resnet50 iteration 3/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 2.96 mins
# Profiling resnet50 iteration 4/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 2.79 mins
# Profiling resnet50 iteration 5/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 2.64 mins
# Profiling resnet50 iteration 6/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 2.48 mins
# Profiling resnet50 iteration 7/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 2.31 mins
# Profiling resnet50 iteration 8/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 2.16 mins
# Profiling resnet50 iteration 9/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 2.01 mins
# Profiling resnet50 iteration 10/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 1.85 mins
# Profiling resnet50 iteration 11/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 1.70 mins
# Profiling resnet50 iteration 12/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 1.54 mins
# Profiling resnet50 iteration 13/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 1.39 mins
# Profiling resnet50 iteration 14/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 1.23 mins
# Profiling resnet50 iteration 15/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 1.07 mins
# Profiling resnet50 iteration 16/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 0.92 mins
# Profiling resnet50 iteration 17/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 0.77 mins
# Profiling resnet50 iteration 18/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 0.61 mins
# Profiling resnet50 iteration 19/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 0.46 mins
# Profiling resnet50 iteration 20/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.15mins per profile on resnet50, estimated time left 0.30 mins
# Allowing GPUs to cool between models ...
# Profiling resnet101 iteration 1/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet101/resnet101%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet101
# Average 0.35mins per profile on resnet101, estimated time left 7.37 mins
# Profiling resnet101 iteration 2/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet101/resnet101%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet101
# Average 0.27mins per profile on resnet101, estimated time left 5.52 mins
# Profiling resnet101 iteration 3/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet101/resnet101%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet101
# Average 0.25mins per profile on resnet101, estimated time left 4.79 mins
# Profiling resnet101 iteration 4/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet101/resnet101%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet101
# Average 0.24mins per profile on resnet101, estimated time left 4.32 mins
# Profiling resnet101 iteration 5/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet101/resnet101%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet101
# Average 0.23mins per profile on resnet101, estimated time left 3.94 mins
# Profiling resnet101 iteration 6/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet101/resnet101%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet101
# Average 0.22mins per profile on resnet101, estimated time left 3.62 mins
# Profiling resnet101 iteration 7/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet101/resnet101%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet101
# Average 0.22mins per profile on resnet101, estimated time left 3.34 mins
# Profiling resnet101 iteration 8/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet101/resnet101%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet101
# Average 0.22mins per profile on resnet101, estimated time left 3.08 mins
# Profiling resnet101 iteration 9/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet101/resnet101%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet101
# Average 0.21mins per profile on resnet101, estimated time left 2.83 mins
# Profiling resnet101 iteration 10/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet101/resnet101%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet101
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/subprocess.py", line 1154, in communicate
#     stdout, stderr = self._communicate(input, endtime, timeout)
#   File "/usr/lib/python3.10/subprocess.py", line 2021, in _communicate
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.10/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/collect_tf_profiles.py", line 157, in <module>
#     success, file, output = run_command(model_folder, command)
#   File "/content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/collect_tf_profiles.py", line 26, in run_command
#     output = subprocess.run(shlex.split(command), capture_output=True, text=True)
#   File "/usr/lib/python3.10/subprocess.py", line 505, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/usr/lib/python3.10/subprocess.py", line 1165, in communicate
#     self._wait(timeout=sigint_timeout)
#   File "/usr/lib/python3.10/subprocess.py", line 1933, in _wait
#     endtime = _time() + timeout
# KeyboardInterrupt
# ^C
