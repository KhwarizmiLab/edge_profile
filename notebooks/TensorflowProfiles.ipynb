# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-20ad6743-54d7-dbf8-f3fc-bc4a6a6dc3f8)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

if os.path.isdir("/content/drive/MyDrive/EZClone/edge_profile"):
    # %cd "/content/drive/MyDrive/EZClone/edge_profile"
# Out:
# /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile

# %%
# !pip install transformers

# %%
import tensorflow as tf
print(tf.__version__)
tf.config.list_physical_devices('GPU')
# Out:
# 2.17.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !python collect_tf_profiles.py -i 20 -input 0 -folder colab_zero_tf
# Out:
# Profiling resnet50 iteration 1/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# Average 0.33mins per profile on resnet50, estimated time left 7.11 mins
# Profiling resnet50 iteration 2/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/resnet50/resnet50%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model resnet50
# ...

# %%
# !python collect_tf_profiles.py -i 20 -input 0 -folder colab_zero_tf
# Out:
# Profiling inception_v3 iteration 1/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/inception_v3/inception_v3%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model inception_v3
# Average 0.28mins per profile on inception_v3, estimated time left 6.08 mins
# Profiling inception_v3 iteration 2/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/inception_v3/inception_v3%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model inception_v3
# ...

# %%
# !python collect_tf_profiles.py -i 20 -input 0 -folder colab_zero_tf
# Out:
# Profiling xlm_roberta iteration 1/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/xlm_roberta/xlm_roberta%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model xlm_roberta
# Average 0.88mins per profile on xlm_roberta, estimated time left 18.5 mins
# Profiling xlm_roberta iteration 2/20
# Running: nvprof --csv --log-file /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/profiles/tesla_t4/colab_zero_tf/xlm_roberta/xlm_roberta%p.csv --system-profiling on --profile-child-processes python /content/drive/.shortcut-targets-by-id/1Au4zMNJ9580N0LEVY-hkpoqqwtea3zM-/EZClone/edge_profile/tensorflow/model_inference.py -n 10 -gpu 0 -model xlm_roberta
# ...
